# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
DATASET_CSABSTRUCT_DIR = './gdrive/Shareddrives/DATASETS/CSAbstruct/'
OUTPUT_MODEL_DIR = './gdrive/Shareddrives/MODELS/'

# %%
# !pip install transformers -q
# !pip install sentence_transformers -q
# !pip install datasets -q
# Out:
#      |████████████████████████████████| 4.7 MB 7.6 MB/s
#      |████████████████████████████████| 101 kB 12.6 MB/s
#      |████████████████████████████████| 596 kB 68.4 MB/s
#      |████████████████████████████████| 6.6 MB 89.0 MB/s
#      |████████████████████████████████| 85 kB 4.1 MB/s
#      |████████████████████████████████| 1.2 MB 61.1 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done
#      |████████████████████████████████| 365 kB 7.9 MB/s
#      |████████████████████████████████| 115 kB 74.2 MB/s
#      |████████████████████████████████| 141 kB 78.4 MB/s
#      |████████████████████████████████| 212 kB 71.7 MB/s
#      |████████████████████████████████| 127 kB 77.5 MB/s

# %%
import pandas as pd

# %%
df_train = pd.read_parquet(DATASET_CSABSTRUCT_DIR + 'train.parquet')
df_dev = pd.read_parquet(DATASET_CSABSTRUCT_DIR + 'dev.parquet')
df_test = pd.read_parquet(DATASET_CSABSTRUCT_DIR + 'test.parquet')

# %%
df_train.columns
# Out:
# Index(['id', 'sentence', 'subject_label', 'label_id'], dtype='object')

# %%
df_train['label_id'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df_train[['subject_label', 'label_id']].drop_duplicates()
# Out:
#    subject_label  label_id
# 0     background         0
# 1      objective         1
# 2         method         2
# 4         result         3
# 67         other         4

# %%
# same text but with different labels
print(f'{len(df_train.index)}')
mask = df_train.groupby('sentence')['label_id'].transform('nunique') > 1
df_train = df_train[~mask].copy()
print(f'{len(df_train.index)}')
# Out:
# 11333
# 11250

# %%
# same text but with different labels
print(f'{len(df_dev.index)}')
mask = df_dev.groupby('sentence')['label_id'].transform('nunique') > 1
df_dev = df_dev[~mask].copy()
print(f'{len(df_dev.index)}')
# Out:
# 2026
# 2024

# %%
# same text but with different labels
print(f'{len(df_test.index)}')
mask = df_test.groupby('sentence')['label_id'].transform('nunique') > 1
df_test = df_test[~mask].copy()
print(f'{len(df_test.index)}')
# Out:
# 1349
# 1349

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased", model_max_length=512)
# Out:
# Downloading config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/223k [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
  tokenized_sentence = tokenizer(examples["sentence"], truncation=True)
  tokenized_sentence['label'] = examples['label_id']
  return tokenized_sentence

# %%
from datasets import Dataset

dataset_train = Dataset.from_pandas(df_train)
dataset_val = Dataset.from_pandas(df_dev)
dataset_test = Dataset.from_pandas(df_test)

# %%
dataset_train = dataset_train.map(preprocess_function)
dataset_val = dataset_val.map(preprocess_function)
dataset_test = dataset_test.map(preprocess_function)
# Out:
#   0%|          | 0/11250 [00:00<?, ?ex/s]
#   0%|          | 0/2024 [00:00<?, ?ex/s]
#   0%|          | 0/1349 [00:00<?, ?ex/s]

# %%
label2id = {'background': 0, 'objective': 1, 'method': 2, 'result': 3, 'other': 4}
id2label = {0: 'background', 1: 'objective', 2: 'method', 3: 'result', 4: 'other'}

# %%
from transformers import AutoConfig, AutoModelForSequenceClassification

# Download configuration from huggingface.co and cache.
config = AutoConfig.from_pretrained("allenai/scibert_scivocab_uncased", num_labels=5, id2label=id2label, label2id=label2id)
model = AutoModelForSequenceClassification.from_config(config)

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./results",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=20,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_total_limit=2,
    save_strategy="epoch",
    load_best_model_at_end=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset_train,
    eval_dataset=dataset_val,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 11250
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 14080
#     <div>
#
#       <progress value='14080' max='14080' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14080/14080 31:17, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.391400</td>
#       <td>1.243852</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.231200</td>
#       <td>1.145303</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.005700</td>
#       <td>1.196041</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.923500</td>
#       <td>1.202617</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.804500</td>
#       <td>1.315722</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.692000</td>
#       <td>1.422711</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.632500</td>
#       <td>1.435719</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.525300</td>
#       <td>1.647757</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.445800</td>
#       <td>1.846971</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.360400</td>
#       <td>1.912609</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.322400</td>
#       <td>2.055678</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.290500</td>
#       <td>2.399114</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.256300</td>
#       <td>2.756474</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.226800</td>
#       <td>2.571602</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.181700</td>
#       <td>3.001563</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.172400</td>
#       <td>3.214275</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.154100</td>
#       <td>3.137102</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.116900</td>
#       <td>3.346966</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.123400</td>
#       <td>3.417457</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.103900</td>
#       <td>3.504898</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-704
# Configuration saved in ./results/checkpoint-704/config.json
# Model weights saved in ./results/checkpoint-704/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-704/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-704/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-1408
# Configuration saved in ./results/checkpoint-1408/config.json
# Model weights saved in ./results/checkpoint-1408/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-1408/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-1408/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-2112
# Configuration saved in ./results/checkpoint-2112/config.json
# Model weights saved in ./results/checkpoint-2112/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-2112/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-2112/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-704] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-2816
# Configuration saved in ./results/checkpoint-2816/config.json
# Model weights saved in ./results/checkpoint-2816/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-2816/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-2816/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-2112] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-3520
# Configuration saved in ./results/checkpoint-3520/config.json
# Model weights saved in ./results/checkpoint-3520/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-3520/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-3520/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-2816] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-4224
# Configuration saved in ./results/checkpoint-4224/config.json
# Model weights saved in ./results/checkpoint-4224/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-4224/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-4224/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-3520] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-4928
# Configuration saved in ./results/checkpoint-4928/config.json
# Model weights saved in ./results/checkpoint-4928/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-4928/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-4928/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-4224] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-5632
# Configuration saved in ./results/checkpoint-5632/config.json
# Model weights saved in ./results/checkpoint-5632/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-5632/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-5632/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-4928] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-6336
# Configuration saved in ./results/checkpoint-6336/config.json
# Model weights saved in ./results/checkpoint-6336/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-6336/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-6336/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-5632] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-7040
# Configuration saved in ./results/checkpoint-7040/config.json
# Model weights saved in ./results/checkpoint-7040/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-7040/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-7040/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-6336] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-7744
# Configuration saved in ./results/checkpoint-7744/config.json
# Model weights saved in ./results/checkpoint-7744/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-7744/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-7744/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-7040] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-8448
# Configuration saved in ./results/checkpoint-8448/config.json
# Model weights saved in ./results/checkpoint-8448/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-8448/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-8448/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-7744] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-9152
# Configuration saved in ./results/checkpoint-9152/config.json
# Model weights saved in ./results/checkpoint-9152/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-9152/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-9152/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-8448] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-9856
# Configuration saved in ./results/checkpoint-9856/config.json
# Model weights saved in ./results/checkpoint-9856/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-9856/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-9856/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-9152] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-10560
# Configuration saved in ./results/checkpoint-10560/config.json
# Model weights saved in ./results/checkpoint-10560/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-10560/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-10560/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-9856] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-11264
# Configuration saved in ./results/checkpoint-11264/config.json
# Model weights saved in ./results/checkpoint-11264/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-11264/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-11264/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-10560] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-11968
# Configuration saved in ./results/checkpoint-11968/config.json
# Model weights saved in ./results/checkpoint-11968/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-11968/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-11968/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-11264] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-12672
# Configuration saved in ./results/checkpoint-12672/config.json
# Model weights saved in ./results/checkpoint-12672/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-12672/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-12672/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-11968] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-13376
# Configuration saved in ./results/checkpoint-13376/config.json
# Model weights saved in ./results/checkpoint-13376/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-13376/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-13376/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-12672] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2024
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-14080
# Configuration saved in ./results/checkpoint-14080/config.json
# Model weights saved in ./results/checkpoint-14080/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-14080/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-14080/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-13376] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./results/checkpoint-1408 (score: 1.14530348777771).
# TrainOutput(global_step=14080, training_loss=0.4865468857301907, metrics={'train_runtime': 1880.0824, 'train_samples_per_second': 119.676, 'train_steps_per_second': 7.489, 'total_flos': 6623378442163824.0, 'train_loss': 0.4865468857301907, 'epoch': 20.0})

# %%
predictions = trainer.predict(dataset_test)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, subject_label, id, label_id, __index_level_0__. If sentence, subject_label, id, label_id, __index_level_0__ are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1349
#   Batch size = 16

# %%
from datasets import load_metric
import numpy as np

def compute_metrics(eval_pred):
  metric_acc = load_metric("accuracy")
  metric_p = load_metric("precision")
  metric_r = load_metric("recall")
  metric_f1 = load_metric("f1")
    
  preds = eval_pred.predictions
  labels = eval_pred.label_ids
  predictions = np.argmax(preds, axis=-1)

  accuracy = metric_acc.compute(predictions=predictions, references=labels)
  #precision = metric_p.compute(predictions=predictions, references=labels)
  #recall = metric_r.compute(predictions=predictions, references=labels)
  f1 = metric_f1.compute(predictions=predictions, references=labels, average="micro")
  
  return accuracy, f1

# %%
compute_metrics(predictions)
# Out:
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.58k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.52k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# ({'accuracy': 0.6641957005189029}, {'f1': 0.6641957005189029})

# %%
OUTPUT_MODEL_DIR = './gdrive/Shareddrives/MODELS/'

model.save_pretrained(OUTPUT_MODEL_DIR + 'csabstruct_classification')
# Out:
# Configuration saved in ./gdrive/Shareddrives/MODELS/csabstruct_classification/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/csabstruct_classification/pytorch_model.bin
