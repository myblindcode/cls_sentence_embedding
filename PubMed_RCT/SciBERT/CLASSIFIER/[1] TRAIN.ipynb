# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
DATASET_PUBMED_RCT_DIR = './gdrive/Shareddrives/DATASETS/PUBMED_RCT/'
OUTPUT_MODEL_DIR = './gdrive/Shareddrives/MODELS/'

# %%
# !pip install transformers -q
# !pip install sentence_transformers -q
# !pip install datasets -q
# Out:
#      |████████████████████████████████| 4.7 MB 4.3 MB/s
#      |████████████████████████████████| 101 kB 10.4 MB/s
#      |████████████████████████████████| 596 kB 49.1 MB/s
#      |████████████████████████████████| 6.6 MB 35.9 MB/s
#      |████████████████████████████████| 85 kB 2.5 MB/s
#      |████████████████████████████████| 1.2 MB 23.5 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done
#      |████████████████████████████████| 365 kB 4.3 MB/s
#      |████████████████████████████████| 141 kB 49.6 MB/s
#      |████████████████████████████████| 115 kB 48.9 MB/s
#      |████████████████████████████████| 212 kB 49.3 MB/s
#      |████████████████████████████████| 127 kB 48.9 MB/s

# %%
import pandas as pd

# %%
df_train = pd.read_parquet(DATASET_PUBMED_RCT_DIR + 'train.parquet')
df_dev = pd.read_parquet(DATASET_PUBMED_RCT_DIR + 'dev.parquet')
df_test = pd.read_parquet(DATASET_PUBMED_RCT_DIR + 'test.parquet')

# %%
df_train.columns
# Out:
# Index(['pmid', 'label', 'sentence', 'label_id'], dtype='object')

# %%
df_train['label_id'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df_train[['label', 'label_id']].drop_duplicates()
# Out:
#           label  label_id
# 0     objective         0
# 1       methods         1
# 6       results         2
# 11  conclusions         3
# 12   background         4

# %%
# same text but with different labels
print(f'{len(df_train.index)}')
mask = df_train.groupby('sentence')['label_id'].transform('nunique') > 1
df_train = df_train[~mask].copy()
print(f'{len(df_train.index)}')
# Out:
# 180040
# 179892

# %%
# same text but with different labels
print(f'{len(df_dev.index)}')
mask = df_dev.groupby('sentence')['label_id'].transform('nunique') > 1
df_dev = df_dev[~mask].copy()
print(f'{len(df_dev.index)}')
# Out:
# 30212
# 30212

# %%
# same text but with different labels
print(f'{len(df_test.index)}')
mask = df_test.groupby('sentence')['label_id'].transform('nunique') > 1
df_test = df_test[~mask].copy()
print(f'{len(df_test.index)}')
# Out:
# 30135
# 30122

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased", model_max_length=512)
# Out:
# Downloading config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/223k [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
  tokenized_sentence = tokenizer(examples["sentence"], truncation=True)
  tokenized_sentence['label'] = examples['label_id']
  return tokenized_sentence

# %%
from datasets import Dataset

dataset_train = Dataset.from_pandas(df_train)
dataset_val = Dataset.from_pandas(df_dev)
dataset_test = Dataset.from_pandas(df_test)

# %%
dataset_train = dataset_train.map(preprocess_function)
dataset_val = dataset_val.map(preprocess_function)
dataset_test = dataset_test.map(preprocess_function)
# Out:
#   0%|          | 0/179892 [00:00<?, ?ex/s]
#   0%|          | 0/30212 [00:00<?, ?ex/s]
#   0%|          | 0/30122 [00:00<?, ?ex/s]

# %%
label2id = {'objective': 0, 'methods': 1, 'results': 2, 'conclusions': 3, 'background': 4}
id2label = {0: 'objective', 1: 'methods', 2: 'results', 3: 'conclusions', 4: 'background'}

# %%
from transformers import AutoConfig, AutoModelForSequenceClassification

# Download configuration from huggingface.co and cache.
config = AutoConfig.from_pretrained("allenai/scibert_scivocab_uncased", num_labels=5, id2label=id2label, label2id=label2id)
model = AutoModelForSequenceClassification.from_config(config)

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir=OUTPUT_MODEL_DIR + 'pubmed_rct_classification/checkpoint',
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=20,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_total_limit=2,
    save_strategy="epoch",
    load_best_model_at_end=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset_train,
    eval_dataset=dataset_val,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 179892
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 224880
#     <div>
#
#       <progress value='224880' max='224880' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [224880/224880 11:16:58, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.542900</td>
#       <td>0.506363</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.476400</td>
#       <td>0.479497</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.440800</td>
#       <td>0.482357</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.393300</td>
#       <td>0.512598</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.336500</td>
#       <td>0.516175</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.314100</td>
#       <td>0.568344</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.265600</td>
#       <td>0.671993</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.242100</td>
#       <td>0.738909</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.226700</td>
#       <td>0.886328</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.199400</td>
#       <td>0.888216</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.172600</td>
#       <td>0.949158</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.152900</td>
#       <td>1.076981</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.121800</td>
#       <td>1.187699</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.103300</td>
#       <td>1.348046</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.084600</td>
#       <td>1.384880</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.079000</td>
#       <td>1.495103</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.060900</td>
#       <td>1.538552</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.033000</td>
#       <td>1.623479</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.031700</td>
#       <td>1.695222</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.037800</td>
#       <td>1.723417</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-11244
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-11244/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-11244/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-11244/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-11244/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-22488
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-22488/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-22488/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-22488/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-22488/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-33732
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-33732/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-33732/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-33732/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-33732/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-11244] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-44976
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-44976/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-44976/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-44976/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-44976/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-33732] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-56220
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-56220/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-56220/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-56220/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-56220/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-44976] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-67464
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-67464/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-67464/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-67464/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-67464/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-56220] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-78708
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-78708/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-78708/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-78708/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-78708/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-67464] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-89952
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-89952/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-89952/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-89952/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-89952/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-78708] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-101196
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-101196/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-101196/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-101196/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-101196/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-89952] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-112440
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-112440/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-112440/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-112440/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-112440/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-101196] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-123684
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-123684/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-123684/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-123684/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-123684/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-112440] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-134928
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-134928/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-134928/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-134928/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-134928/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-123684] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-146172
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-146172/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-146172/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-146172/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-146172/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-134928] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-157416
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-157416/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-157416/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-157416/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-157416/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-146172] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-168660
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-168660/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-168660/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-168660/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-168660/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-157416] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-179904
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-179904/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-179904/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-179904/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-179904/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-168660] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-191148
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-191148/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-191148/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-191148/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-191148/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-179904] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-202392
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-202392/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-202392/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-202392/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-202392/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-191148] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-213636
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-213636/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-213636/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-213636/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-213636/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-202392] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: __index_level_0__, sentence, pmid, label_id. If __index_level_0__, sentence, pmid, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30212
#   Batch size = 16
# Saving model checkpoint to ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-224880
# Configuration saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-224880/config.json
# Model weights saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-224880/pytorch_model.bin
# tokenizer config file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-224880/tokenizer_config.json
# Special tokens file saved in ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-224880/special_tokens_map.json
# Deleting older checkpoint [gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-213636] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./gdrive/Shareddrives/MODELS/pubmed_rct_classification/checkpoint/checkpoint-22488 (score: 0.47949689626693726).
# TrainOutput(global_step=224880, training_loss=0.220772381029872, metrics={'train_runtime': 40620.9058, 'train_samples_per_second': 88.571, 'train_steps_per_second': 5.536, 'total_flos': 1.507812945775578e+17, 'train_loss': 0.220772381029872, 'epoch': 20.0})

# %%
predictions = trainer.predict(dataset_test)

# %%
from datasets import load_metric
import numpy as np

def compute_metrics(eval_pred):
  metric_acc = load_metric("accuracy")
  metric_p = load_metric("precision")
  metric_r = load_metric("recall")
  metric_f1 = load_metric("f1")
    
  preds = eval_pred.predictions
  labels = eval_pred.label_ids
  predictions = np.argmax(preds, axis=-1)

  accuracy = metric_acc.compute(predictions=predictions, references=labels)
  #precision = metric_p.compute(predictions=predictions, references=labels)
  #recall = metric_r.compute(predictions=predictions, references=labels)
  f1 = metric_f1.compute(predictions=predictions, references=labels, average="micro")
  
  return accuracy, f1

# %%
compute_metrics(predictions)

# %%
OUTPUT_MODEL_DIR = './gdrive/Shareddrives/MODELS/'

model.save_pretrained(OUTPUT_MODEL_DIR + 'pubmed_rct_classification/model')
