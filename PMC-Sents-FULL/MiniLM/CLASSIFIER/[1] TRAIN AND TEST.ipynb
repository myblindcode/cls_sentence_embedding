# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
DATASET_PMC_FULL = './gdrive/Shareddrives/UNICAMP/DOUTORADO/SEGUNDO_ARTIGO/DATASETS/PMC-Sents-FULL/'
OUTPUT_MODEL_DIR = './gdrive/Shareddrives/UNICAMP/DOUTORADO/SEGUNDO_ARTIGO/MODELS/'

# %%
# !pip install transformers -q
# !pip install sentence_transformers -q
# !pip install datasets -q
# Out:
#      |████████████████████████████████| 4.7 MB 9.4 MB/s
#      |████████████████████████████████| 6.6 MB 35.7 MB/s
#      |████████████████████████████████| 596 kB 59.3 MB/s
#      |████████████████████████████████| 101 kB 12.3 MB/s
#      |████████████████████████████████| 85 kB 3.5 MB/s
#      |████████████████████████████████| 1.3 MB 18.9 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done
#      |████████████████████████████████| 365 kB 10.2 MB/s
#      |████████████████████████████████| 212 kB 44.9 MB/s
#      |████████████████████████████████| 115 kB 62.8 MB/s
#      |████████████████████████████████| 141 kB 63.4 MB/s
#      |████████████████████████████████| 127 kB 62.8 MB/s

# %%
import pandas as pd

# %%
df_train = pd.read_parquet(DATASET_PMC_FULL + 'train_full_text_span1.parquet')
df_dev = pd.read_parquet(DATASET_PMC_FULL + 'val_full_text_span1.parquet')
df_test = pd.read_parquet(DATASET_PMC_FULL + 'test_full_text_span1.parquet')

# %%
df_train.columns
# Out:
# Index(['id', 'text', 'label_id'], dtype='object')

# %%
df_train['label_id'].unique()
# Out:
# array([0, 3, 2, 4, 1])

# %%
# same text but with different labels
print(f'{len(df_train.index)}')
mask = df_train.groupby('text')['label_id'].transform('nunique') > 1
df_train = df_train[~mask].copy()
print(f'{len(df_train.index)}')
# Out:
# 138473
# 138473

# %%
# same text but with different labels
print(f'{len(df_dev.index)}')
mask = df_dev.groupby('text')['label_id'].transform('nunique') > 1
df_dev = df_dev[~mask].copy()
print(f'{len(df_dev.index)}')
# Out:
# 17309
# 17309

# %%
# same text but with different labels
print(f'{len(df_test.index)}')
mask = df_test.groupby('text')['label_id'].transform('nunique') > 1
df_test = df_test[~mask].copy()
print(f'{len(df_test.index)}')
# Out:
# 17310
# 17310

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("nreimers/MiniLM-L6-H384-uncased", model_max_length=512)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
  tokenized_sentence = tokenizer(examples["text"], truncation=True)
  tokenized_sentence['label'] = examples['label_id']
  return tokenized_sentence

# %%
from datasets import Dataset

dataset_train = Dataset.from_pandas(df_train)
dataset_val = Dataset.from_pandas(df_dev)
dataset_test = Dataset.from_pandas(df_test)

# %%
dataset_train = dataset_train.map(preprocess_function)
dataset_val = dataset_val.map(preprocess_function)
dataset_test = dataset_test.map(preprocess_function)
# Out:
#   0%|          | 0/138473 [00:00<?, ?ex/s]
#   0%|          | 0/17309 [00:00<?, ?ex/s]
#   0%|          | 0/17310 [00:00<?, ?ex/s]

# %%
label2id = {'background': 0, 'objective': 1, 'method': 2, 'result': 3, 'other': 4}
id2label = {0: 'background', 1: 'objective', 2: 'method', 3: 'result', 4: 'other'}

# %%
from transformers import AutoConfig, AutoModelForSequenceClassification

# Download configuration from huggingface.co and cache.
config = AutoConfig.from_pretrained("nreimers/MiniLM-L6-H384-uncased", num_labels=5, id2label=id2label, label2id=label2id)
model = AutoModelForSequenceClassification.from_config(config)

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./results",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=20,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_total_limit=2,
    save_strategy="epoch",
    load_best_model_at_end=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset_train,
    eval_dataset=dataset_val,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 138473
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 173100
#     <div>
#
#       <progress value='173100' max='173100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [173100/173100 2:27:54, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.831300</td>
#       <td>0.805388</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.775300</td>
#       <td>0.781679</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.701000</td>
#       <td>0.769816</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.662600</td>
#       <td>0.784116</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.640000</td>
#       <td>0.777090</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.592500</td>
#       <td>0.822657</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.563500</td>
#       <td>0.827323</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.502200</td>
#       <td>0.891086</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.469600</td>
#       <td>0.945512</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.397200</td>
#       <td>1.026195</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.364300</td>
#       <td>1.091709</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.344000</td>
#       <td>1.186400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.318400</td>
#       <td>1.337417</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.268100</td>
#       <td>1.347594</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.257400</td>
#       <td>1.426483</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.233100</td>
#       <td>1.496680</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.211100</td>
#       <td>1.634887</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.186300</td>
#       <td>1.683513</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.187800</td>
#       <td>1.751189</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.180700</td>
#       <td>1.783429</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-8655
# Configuration saved in ./results/checkpoint-8655/config.json
# Model weights saved in ./results/checkpoint-8655/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-8655/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-8655/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-17310
# Configuration saved in ./results/checkpoint-17310/config.json
# Model weights saved in ./results/checkpoint-17310/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-17310/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-17310/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-25965
# Configuration saved in ./results/checkpoint-25965/config.json
# Model weights saved in ./results/checkpoint-25965/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-25965/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-25965/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-8655] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-34620
# Configuration saved in ./results/checkpoint-34620/config.json
# Model weights saved in ./results/checkpoint-34620/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-34620/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-34620/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-17310] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-43275
# Configuration saved in ./results/checkpoint-43275/config.json
# Model weights saved in ./results/checkpoint-43275/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-43275/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-43275/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-34620] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-51930
# Configuration saved in ./results/checkpoint-51930/config.json
# Model weights saved in ./results/checkpoint-51930/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-51930/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-51930/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-43275] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-60585
# Configuration saved in ./results/checkpoint-60585/config.json
# Model weights saved in ./results/checkpoint-60585/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-60585/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-60585/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-51930] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-69240
# Configuration saved in ./results/checkpoint-69240/config.json
# Model weights saved in ./results/checkpoint-69240/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-69240/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-69240/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-60585] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-77895
# Configuration saved in ./results/checkpoint-77895/config.json
# Model weights saved in ./results/checkpoint-77895/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-77895/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-77895/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-69240] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-86550
# Configuration saved in ./results/checkpoint-86550/config.json
# Model weights saved in ./results/checkpoint-86550/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-86550/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-86550/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-77895] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-95205
# Configuration saved in ./results/checkpoint-95205/config.json
# Model weights saved in ./results/checkpoint-95205/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-95205/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-95205/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-86550] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-103860
# Configuration saved in ./results/checkpoint-103860/config.json
# Model weights saved in ./results/checkpoint-103860/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-103860/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-103860/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-95205] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-112515
# Configuration saved in ./results/checkpoint-112515/config.json
# Model weights saved in ./results/checkpoint-112515/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-112515/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-112515/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-103860] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-121170
# Configuration saved in ./results/checkpoint-121170/config.json
# Model weights saved in ./results/checkpoint-121170/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-121170/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-121170/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-112515] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-129825
# Configuration saved in ./results/checkpoint-129825/config.json
# Model weights saved in ./results/checkpoint-129825/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-129825/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-129825/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-121170] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-138480
# Configuration saved in ./results/checkpoint-138480/config.json
# Model weights saved in ./results/checkpoint-138480/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-138480/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-138480/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-129825] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-147135
# Configuration saved in ./results/checkpoint-147135/config.json
# Model weights saved in ./results/checkpoint-147135/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-147135/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-147135/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-138480] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-155790
# Configuration saved in ./results/checkpoint-155790/config.json
# Model weights saved in ./results/checkpoint-155790/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-155790/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-155790/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-147135] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-164445
# Configuration saved in ./results/checkpoint-164445/config.json
# Model weights saved in ./results/checkpoint-164445/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-164445/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-164445/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-155790] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text, id, __index_level_0__, label_id. If text, id, __index_level_0__, label_id are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 17309
#   Batch size = 16
# Saving model checkpoint to ./results/checkpoint-173100
# Configuration saved in ./results/checkpoint-173100/config.json
# Model weights saved in ./results/checkpoint-173100/pytorch_model.bin
# tokenizer config file saved in ./results/checkpoint-173100/tokenizer_config.json
# Special tokens file saved in ./results/checkpoint-173100/special_tokens_map.json
# Deleting older checkpoint [results/checkpoint-164445] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./results/checkpoint-25965 (score: 0.7698159217834473).
# TrainOutput(global_step=173100, training_loss=0.4356618184453831, metrics={'train_runtime': 8876.9989, 'train_samples_per_second': 311.982, 'train_steps_per_second': 19.5, 'total_flos': 1.7420390859096588e+16, 'train_loss': 0.4356618184453831, 'epoch': 20.0})

# %%
predictions = trainer.predict(dataset_test)

# %%
from datasets import load_metric
import numpy as np

def compute_metrics(eval_pred):
  metric_acc = load_metric("accuracy")
  metric_p = load_metric("precision")
  metric_r = load_metric("recall")
  metric_f1_macro = load_metric("f1")
  metric_f1_micro = load_metric("f1")
    
  preds = eval_pred.predictions
  labels = eval_pred.label_ids
  predictions = np.argmax(preds, axis=-1)

  accuracy = metric_acc.compute(predictions=predictions, references=labels)
  #precision = metric_p.compute(predictions=predictions, references=labels)
  #recall = metric_r.compute(predictions=predictions, references=labels)
  f1_micro = metric_f1_micro.compute(predictions=predictions, references=labels, average="micro")
  f1_macro = metric_f1_micro.compute(predictions=predictions, references=labels, average="macro")
  
  return {'accuracy': accuracy, 'f1_macro': f1_macro, 'f1_micro': f1_micro}

# %%
compute_metrics(predictions)

# %%
OUTPUT_MODEL_DIR = './gdrive/Shareddrives/UNICAMP/DOUTORADO/SEGUNDO_ARTIGO/MODELS/'

model.save_pretrained(OUTPUT_MODEL_DIR + 'pmc_full_minilm_classification')

# %%
OUTPUT_MODEL_DIR + 'pmc_full_minilm_classification'
